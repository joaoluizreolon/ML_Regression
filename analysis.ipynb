# %%
# import kruskal

from scipy.stats import kruskal, mannwhitneyu
import pandas as pd

alpha = 0.05

# %%
# make a function that executes the Mann-Whitney U test for all pairs of models
def mannwhitneyu_test(df, model_columns, alpha):
    print("Mann-Whitney U test statistic")
    for i in range(len(model_columns)):
        for j in range(i + 1, len(model_columns)):
            u_stat, p_value = mannwhitneyu(
                df[model_columns[i]], df[model_columns[j]], alternative="two-sided"
            )
            print("===========================================")
            print(
                model_columns[i],
                "and",
                model_columns[j],
                ":",
                u_stat,
            )
            print("P-value:", p_value)
            if p_value < alpha:
                print(
                    "REJECT the null hypothesis: There are significant differences between the groups."
                )
            else:
                print(
                    "FAIL TO REJECT the null hypothesis: There are NO significant differences between the groups."
                )

# %% [markdown]
# # Análise dos Regressores

# %%
# Read the data from output.csv
output_df = pd.read_csv("output.csv")

# Extract the columns
knr = output_df["KNR"]
svr = output_df["SVR"]
mlp = output_df["MLP"]
rf = output_df["RF"]
gb = output_df["GB"]
mlr = output_df["MLR"]


#calcule the mean and the standard deviation of the models and save it in a dataframe
mean = [knr.mean(), svr.mean(), mlp.mean(), rf.mean(), gb.mean(), mlr.mean()]
std = [knr.std(), svr.std(), mlp.std(), rf.std(), gb.std(), mlr.std()]
model_columns = ["KNR", "SVR", "MLP", "RF", "GB", "MLR"]
mean_std_df = pd.DataFrame({"Model": model_columns, "Mean": mean, "Std": std})
print(mean_std_df)

#save the dataframe in a csv file
mean_std_df.to_csv("mean_std.csv", index=False)

# Apply the Kruskal-Wallis H-test
h_stat, p_value = kruskal(knr, svr, mlp, rf, gb, mlr)

print("Kruskal-Wallis H-test statistic:", h_stat)
print("P-value:", p_value)

# Interpretation
if p_value < alpha:
    print(
        "Reject the null hypothesis: There are significant differences between the groups.\n"
    )
    # call mannwhitneyu_test
    model_columns = ["KNR", "SVR", "MLP", "RF", "GB", "MLR"]
    mannwhitneyu_test(output_df, model_columns, alpha)

else:
    print(
        "Fail to reject the null hypothesis: There are no significant differences between the groups."
    )
# Out:
#   Model      Mean       Std
# 0   KNR  0.715449  0.024376
# 1   SVR  0.654350  0.018836
# 2   MLP  0.649736  0.015903
# 3    RF  0.605654  0.019858
# 4    GB  0.617934  0.020005
# 5   MLR  0.654863  0.026542
# Kruskal-Wallis H-test statistic: 84.84297520661158
# P-value: 8.120608973429573e-17
# Reject the null hypothesis: There are significant differences between the groups.
#
# Mann-Whitney U test statistic
# ===========================================
# KNR and SVR : 394.0
# P-value: 1.6570792933858787e-07
# REJECT the null hypothesis: There are significant differences between the groups.
# ===========================================
# KNR and MLP : 398.0
# P-value: 9.172772711656482e-08
# REJECT the null hypothesis: There are significant differences between the groups.
# ===========================================
# KNR and RF : 400.0
# P-value: 6.795615128173358e-08
# REJECT the null hypothesis: There are significant differences between the groups.
# ===========================================
# KNR and GB : 400.0
# P-value: 6.795615128173358e-08
# REJECT the null hypothesis: There are significant differences between the groups.
# ===========================================
# KNR and MLR : 390.0
# P-value: 2.959753733675675e-07
# REJECT the null hypothesis: There are significant differences between the groups.
# ===========================================
# SVR and MLP : 233.0
# P-value: 0.379331935127312
# FAIL TO REJECT the null hypothesis: There are NO significant differences between the groups.
# ===========================================
# SVR and RF : 389.0
# P-value: 3.415575693503718e-07
# REJECT the null hypothesis: There are significant differences between the groups.
# ===========================================
# SVR and GB : 364.0
# P-value: 9.747975903084567e-06
# REJECT the null hypothesis: There are significant differences between the groups.
# ===========================================
# SVR and MLR : 184.0
# P-value: 0.6750141566504884
# FAIL TO REJECT the null hypothesis: There are NO significant differences between the groups.
# ===========================================
# MLP and RF : 388.0
# P-value: 3.938805472866588e-07
# REJECT the null hypothesis: There are significant differences between the groups.
# ===========================================
# MLP and GB : 358.0
# P-value: 2.0407139096244576e-05
# REJECT the null hypothesis: There are significant differences between the groups.
# ===========================================
# MLP and MLR : 159.0
# P-value: 0.2732851201810752
# FAIL TO REJECT the null hypothesis: There are NO significant differences between the groups.
# ===========================================
# RF and GB : 139.0
# P-value: 0.10172863141500606
# FAIL TO REJECT the null hypothesis: There are NO significant differences between the groups.
# ===========================================
# RF and MLR : 32.0
# P-value: 5.873574095711034e-06
# REJECT the null hypothesis: There are significant differences between the groups.
# ===========================================
# GB and MLR : 53.0
# P-value: 7.406402731628529e-05
# REJECT the null hypothesis: There are significant differences between the groups.
